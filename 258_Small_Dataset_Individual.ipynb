# %%
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

import numpy as np
import gensim
import string

from keras.callbacks import LambdaCallback
from keras.layers.recurrent import LSTM
from keras.layers.embeddings import Embedding
from keras.layers import Dense, Activation
from keras.models import Sequential
from keras.utils.data_utils import get_file

path="company_file_preprocessed_small.txt"

print('\nPreparing the sentences...')
max_sentence_len = 40
with open(path) as file_:
    docs = file_.readlines()
sentences = [[word for word in doc.lower().translate(string.punctuation).split()[:max_sentence_len]] for doc in docs]
print('Num sentences:', len(sentences))

print('\nTraining word2vec...')
word_model = gensim.models.Word2Vec(sentences, size=100, min_count=1, window=5, iter=100)
pretrained_weights = word_model.wv.syn0
vocab_size, emdedding_size = pretrained_weights.shape
print('Result embedding shape:', pretrained_weights.shape)
print('Checking similar words:')
for word in ['model', 'network', 'train', 'learn']:
    most_similar = ', '.join('%s (%.2f)' % (similar, dist) for similar, dist in word_model.most_similar(word)[:8])
    print('  %s -> %s' % (word, most_similar))

def word2idx(word):
    return word_model.wv.vocab[word].index
def idx2word(idx):
    return word_model.wv.index2word[idx]

print('\nPreparing the data for LSTM...')
train_x = np.zeros([len(sentences), max_sentence_len], dtype=np.int32)
train_y = np.zeros([len(sentences)], dtype=np.int32)
for i, sentence in enumerate(sentences):
    for t, word in enumerate(sentence[:-1]):
        train_x[i, t] = word2idx(word)
    train_y[i] = word2idx(sentence[-1])
print('train_x shape:', train_x.shape)
print('train_y shape:', train_y.shape)

print('\nTraining LSTM...')
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=emdedding_size, weights=[pretrained_weights]))
model.add(LSTM(units=emdedding_size))
model.add(Dense(units=vocab_size))
model.add(Activation('softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

def sample(preds, temperature=1.0):
    if temperature <= 0:
        return np.argmax(preds)
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def generate_next(text, num_generated=10):
    word_idxs = [word2idx(word) for word in text.lower().split()]
    for i in range(num_generated):
        prediction = model.predict(x=np.array(word_idxs))
        idx = sample(prediction[-1], temperature=0.7)
        word_idxs.append(idx)
    return ' '.join(idx2word(idx) for idx in word_idxs)

def on_epoch_end(epoch, _):
    print('\nGenerating text after epoch: %d' % epoch)
    texts = ['san jose','stockholm stock exchange','headquarter','finance']
    for text in texts:
        sample = generate_next(text)
        print('%s... -> %s' % (text, sample))

model.fit(train_x, train_y,
          batch_size=128,
          epochs=25,
          callbacks=[LambdaCallback(on_epoch_end=on_epoch_end)])
# Out:
# Preparing the sentences...
# Num sentences: 2708
#
# Training word2vec...
# Result embedding shape: (15306, 100)
# Checking similar words:
#   model -> focus (0.60), comprehensive (0.57), segmentsh (0.57), centralized (0.57), cheap (0.56), freemium (0.55), helps (0.55), take (0.54)
#   network -> radio (0.58), service (0.57), satellite (0.54), system (0.53), internet (0.53), tdlte (0.51), telecommunications (0.51), channel (0.49)
#   train -> passenger (0.75), gw (0.66), railway (0.61), atsumi (0.61), luncheon (0.61), crossplatform (0.58), gauldal (0.58), cruises (0.57)
#   learn -> votizens (0.94), elections (0.82), calls (0.78), reach (0.72), caters (0.71), assigned (0.69), securely (0.69), looking (0.69)
#
# Preparing the data for LSTM...
# train_x shape: (2708, 40)
# train_y shape: (2708,)
#
# Training LSTM...
# Epoch 1/25
# 2708/2708 [==============================] - 6s 2ms/step - loss: 9.3170
#
# Generating text after epoch: 0
# san jose... -> san jose metropolitanvickers usa+ premises wars funding host blends java menashy malt
# stockholm stock exchange... -> stockholm stock exchange selfdistributed hamminkeln consultant atlanta tab chair pindling regulations sam farnell
# headquarter... -> headquarter everywhere wooden noire chairing theme bhc xbiz flushometer 1987 nakagawa
# finance... -> finance underwear olof blackfella yaxing visible kiosk charles madras newport nortonvilliers
# Epoch 2/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 7.1670
#
# Generating text after epoch: 1
# san jose... -> san jose florentine smoked gizmodo surgery selected estate pioneer hiring people papgmcsf
# stockholm stock exchange... -> stockholm stock exchange patented aeolianamerican ski haechandle caseboll distillers leads 29 toggenburger gamil
# headquarter... -> headquarter northwest lbc nancy realnetworks camila gti smallmolecule burroughs asics meyers
# finance... -> finance discontinued l djakarta edward refer onyx fx cosmodrome trademark ashland
# Epoch 3/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.5749
#
# Generating text after epoch: 2
# san jose... -> san jose weightless motorcoach eiendom wales monroeville artdink 1800 wsfs motion fighter
# stockholm stock exchange... -> stockholm stock exchange mandal 5034 educationtechnology find 73 gvidi alfred maykor jason saas
# headquarter... -> headquarter vicky lionsgate egm ishq grass florian 20th metals+ ukbased voicebanks
# finance... -> finance branches+ corporation noodles beneful mso touchstone financier unlimited incident 89000
# Epoch 4/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.5110
#
# Generating text after epoch: 3
# san jose... -> san jose pioneered richards disputes laurens slovakia lansing omniplex 74 loadersh caterpillar
# stockholm stock exchange... -> stockholm stock exchange resource cover subsdiary aspects wearprotection bellflower value cross subsidiary bedford
# headquarter... -> headquarter meteorological harmony approx controversyh across mayfairwith dvb maseca levitskiy inserted
# finance... -> finance 1893 equals6 kunuk licks ipad 1000squarefoot babul fostergrant banner transport
# Epoch 5/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4929
#
# Generating text after epoch: 4
# san jose... -> san jose helicopters remeha jerrold muhammed structures stephanskirchen facilitation 195 traditionally xiv
# stockholm stock exchange... -> stockholm stock exchange comparison kilometres sametime da bancshares halpern ibmsecu watermelon elementary 1722
# headquarter... -> headquarter christiano curbstone especially yandal syria+ despite 1974 drugs matroid realtors
# finance... -> finance newhaven knightsbridge corazon historyh taken mln cies andritz corbin toyota
# Epoch 6/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4819
#
# Generating text after epoch: 5
# san jose... -> san jose ansul mandell massachusettsbased fabrication hilander redmond multiplatform farbwerke navabi edmark
# stockholm stock exchange... -> stockholm stock exchange provider modani universities works badminton battista upgrade comprises syndication 10
# headquarter... -> headquarter spectron danish safe asian uncommonly cattle artisans allies ant 475
# finance... -> finance dot 1846 greater public edf intermediary catalyst scheduled portion bidding
# Epoch 7/25
# 2708/2708 [==============================] - 5s 2ms/step - loss: 6.4767
#
# Generating text after epoch: 6
# san jose... -> san jose sinofert accelerator rated 1950s major overviewh bookmarking identities advisor bankas
# stockholm stock exchange... -> stockholm stock exchange distinct rvca pvt explosives broader bhubaneswar louise pelion backgroundh homeburgers
# headquarter... -> headquarter dredging acoustics previously plant newmarket mississauga cn master time choose
# finance... -> finance sex farnell agreement commercializing cbs benelli 1990s use+ project perhaps
# Epoch 8/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4744
#
# Generating text after epoch: 7
# san jose... -> san jose markus energizer seafoodmccormick million1260000squarefoot secure irvine preov 39 jeweler chatime
# stockholm stock exchange... -> stockholm stock exchange development employs sandwiched makino rum subsidiarynew motovilikha donatos lingerie corpore
# headquarter... -> headquarter 145000 tal coffeehouse horological 8024 francoitalian victor carburetor dedicated business
# finance... -> finance workstations van lot hc27u jiao merchandise michael offshoot sauce+ crosschannel
# Epoch 9/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4703
#
# Generating text after epoch: 8
# san jose... -> san jose zainal extrusion rwanda syndicated installed commonly maritime highend lipsticks football
# stockholm stock exchange... -> stockholm stock exchange triumph buytolet scientific haas fitness but rifts 1859 extract 1984present
# headquarter... -> headquarter dinamic sender decades boltonbybowland diversification outsourced accessible iso reverse ultragaz
# finance... -> finance ren glpcompliant hunt bunnies oliphant failed terni maryland oncology town
# Epoch 10/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4720
#
# Generating text after epoch: 9
# san jose... -> san jose stylized governed metro patagonia sector+ go dambuster moses tiles+ duopoly
# stockholm stock exchange... -> stockholm stock exchange nuremberg mover consumer streamlines easts noire compellents marex immunotherapy awards
# headquarter... -> headquarter multinational solution focused frigate exchanges reviews microscopes playing within whose
# finance... -> finance bearh exor fenceless dsseldorf 12005 australia+ breath strains mobyland redwood
# Epoch 11/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4687
#
# Generating text after epoch: 10
# san jose... -> san jose 2016h expediacom sugarinstant awash 101 coastline immersion gate entertainment billion
# stockholm stock exchange... -> stockholm stock exchange stake jolly syria perhaps apeldoorn pubs geelong mediehuset lippincott robin
# headquarter... -> headquarter rig cult liability territory sociedad etymologyh experts h thus dab
# finance... -> finance ide plays neuromuscular partners 1878 assurance ireland athena trampoline 1939
# Epoch 12/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4656
#
# Generating text after epoch: 11
# san jose... -> san jose instinet suborbital cowell keyless toboll floorcovering aimed compete blackbird 175
# stockholm stock exchange... -> stockholm stock exchange moderateincome housed 686 20th enix lds productionsh 1910 altavoz administrationh
# headquarter... -> headquarter jea concerning fixedline newstone upon schulzdornburg russe 2016+ ecommerce aadhi
# finance... -> finance document audiovisual aaa 704games centros altenberge suites bandicoot 821km ranged
# Epoch 13/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4664
#
# Generating text after epoch: 12
# san jose... -> san jose machinefabriek downloads banca franciscos therapy lecturer awamleh finance forced kemco
# stockholm stock exchange... -> stockholm stock exchange recorded bergamo slightly tiltware chains sequencing soft solna fee established
# headquarter... -> headquarter miami faktorowicz moser bedding badenwrttemberg hwange pleasant 1853 leicestershire great
# finance... -> finance amstrad cameroon akemann donetsk rhinewestphalia johns shirts impax soup2nuts intarcia
# Epoch 14/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4624
#
# Generating text after epoch: 13
# san jose... -> san jose breaches masculine vacuums catholic patents world world ratpac wasp technologiesh
# stockholm stock exchange... -> stockholm stock exchange issues jy come newsprint editing+ produce luchtverkeersleiding moyes albers joyce
# headquarter... -> headquarter grinding fifteen dakota formulation unibet anna fabrics 1766 minister men
# finance... -> finance stretch interconnect valuations intermodal glendora motorcars affected wolffpetersen orleans consultants
# Epoch 15/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4654
#
# Generating text after epoch: 14
# san jose... -> san jose fairey stec johns suites secondhand looking central cooperates print partap
# stockholm stock exchange... -> stockholm stock exchange primary hrsholm everard motovudu australian helps sogna pax bro rinat
# headquarter... -> headquarter milchan yazoo tacos experiment engineer caterers bulk talk administering transitory
# finance... -> finance competing pprovider patterson bestknown broken biovistas cooking pictures savoury thrive15
# Epoch 16/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4620
#
# Generating text after epoch: 15
# san jose... -> san jose twelve police egypt levi cell skopje banco swartz prices flowers
# stockholm stock exchange... -> stockholm stock exchange banfoandes lefebvre lansing uri project tigheim modelh sorcerer platform housing
# headquarter... -> headquarter catholic hello farmerowned termination nonfood zylog inkjet anechoic wiener english
# finance... -> finance loudspeakers remembered seattle heon stanford harvest border 800 claude usingers
# Epoch 17/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4614
#
# Generating text after epoch: 16
# san jose... -> san jose findwell simon basell walker clobber bioeffectives develops eads amrutanjan 07302
# stockholm stock exchange... -> stockholm stock exchange hanza assumed atala sheela heritage yinzcam interested lance cctv ibms
# headquarter... -> headquarter times tricolor potomac rgard dienas axalto owning interpublic samruddhi ideas
# finance... -> finance edel sub6 preston localdirector palm elektroprivreda councils included woodwind chennai
# Epoch 18/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4608
#
# Generating text after epoch: 17
# san jose... -> san jose pindling 1931 caterers rmn preprepared citizens alanonalateen fans aha motovudu
# stockholm stock exchange... -> stockholm stock exchange metal owned gett thomas tracking genre trintoc collectors spa chacha
# headquarter... -> headquarter stortorvet tohart carried biomedical pornographic lionsgate pizza warhol review grind
# finance... -> finance severt 675 tepe known oudenaarde otosan centerfire inkjet retrofittings remington
# Epoch 19/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4598
#
# Generating text after epoch: 18
# san jose... -> san jose rostec archiving autolite however lille gruma empresa biovista town variation
# stockholm stock exchange... -> stockholm stock exchange noted pliers churchills will scarselli sunnipath states corporate wycombe 2017mckesson
# headquarter... -> headquarter gardaworld dre taguig 1900 circumstances koning us10 potomac ebelh community+
# finance... -> finance oakland bodies everything riva desired packaged brett musicianwilliam recognising lands
# Epoch 20/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4610
#
# Generating text after epoch: 19
# san jose... -> san jose graz branches multiple purposes copc forest nongovernmental segments valero laundering
# stockholm stock exchange... -> stockholm stock exchange all ss mouth borlnge netwitness automobile dot tool nonbank commonwealth
# headquarter... -> headquarter 1961 greekbased thf kazar invested trondhjems relations trigger kirkland dany
# finance... -> finance tradebot locates zeltz naming cheshire ivorycolored nextstep brazilian envisioned francis
# Epoch 21/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4611
#
# Generating text after epoch: 20
# san jose... -> san jose registrar senior singleowned trunk cleveland remy linjen peak dellumbria benelli
# stockholm stock exchange... -> stockholm stock exchange media 143 transport four uhi telegames aston starmark kokosboller kleczynski
# headquarter... -> headquarter lee manning powered share replaced bess bromwell massimo billabong wallace
# finance... -> finance spike packs conjunction telegames augustine sanno chrysler logic dinnerware myanma
# Epoch 22/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4586
#
# Generating text after epoch: 21
# san jose... -> san jose recreation download shut ecological noman titlesh structureh mpis alanonalateen thinfilm
# stockholm stock exchange... -> stockholm stock exchange productions ensure masa 625740 yot moderate renamed ferrero 1988 wilsons
# headquarter... -> headquarter stress prato trucks announced panopticon familyowned humanguided dharapadavedu brighton per
# finance... -> finance download lender converted emporis install goopti hobart best wore orlando
# Epoch 23/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4634
#
# Generating text after epoch: 22
# san jose... -> san jose likened aer textured subscribers finmeccanicas pair moore kano entertain tomichan
# stockholm stock exchange... -> stockholm stock exchange just haverty nowexpired castles reggio electronicsh cobalt cheap repole kavanaugh
# headquarter... -> headquarter bergamo extrafarma hunter adecco superunion pidemont sa maksymilian displays refineries
# finance... -> finance eurogroup bramer kroehler proclaiming opi ungagged flavors putnam aquafadas rovs
# Epoch 24/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4602
#
# Generating text after epoch: 23
# san jose... -> san jose array todelta vitello gaeta medianews burgess exists codejock homer beneteau
# stockholm stock exchange... -> stockholm stock exchange began santam devon+ mcdonnell become tradebot orrville digital paterson panama
# headquarter... -> headquarter pub weyerhaeuser definitive auction cumplo specializes retrofittings gerard datacenter gwalia
# finance... -> finance dominic york queens monica adverse tramway wilsons aerostich semi triggers
# Epoch 25/25
# 2708/2708 [==============================] - 4s 1ms/step - loss: 6.4579
#
# Generating text after epoch: 24
# san jose... -> san jose championship magatte ritz roddenberry oncologyh 1700 realized rossh headend winwind
# stockholm stock exchange... -> stockholm stock exchange 1937 lexis accolades bavaria pressure cannabis boy comes matches doing
# headquarter... -> headquarter somalia 471st sky exchangerelated colleges egm artisanal demographic lysaker indigo
# finance... -> finance treatment showcase wrttembergische scale m photographer helsinki ii cctv il476

# %%
print(sentences[0])
# Out:
# ['cmc', 'connect', 'bursonmarsteller', 'is', 'a', 'premier', 'perception', 'management', 'firm', 'that', 'provides', 'communication', 'solutions', 'the', 'company', 'was', 'founded', 'in', '1995', 'by', 'yomi', 'badejo', 'okusanya', 'in', 'ikeja', 'lagos', 'nigeria', 'cmc', 'connect', 'have', 'exclusive', 'affiliation', 'with', 'bursonmarsteller', 'a', 'leading', 'global', 'public', 'relations', 'firm']

# %%
word_model['connect']
# Out:
# /Users/shalu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-6.18535936e-01, -2.48911992e-01, -7.34964013e-01, -9.22909856e-01,
#         4.22672540e-01, -4.03853744e-01, -5.30699268e-04, -4.55677629e-01,
#        -2.70245434e-03,  3.66581529e-01,  3.39169532e-01,  6.94007695e-01,
#         6.69669285e-02, -1.64970737e-02,  1.48683218e-02, -1.34070471e-01,
#         1.73866805e-02, -3.40689152e-01, -4.07985538e-01,  5.53207457e-01,
#         9.71282125e-02,  2.59613335e-01, -7.63405085e-01,  1.15798032e+00,
#         5.36187291e-01, -6.00239396e-01,  4.66108434e-02,  6.54145718e-01,
#        -3.19673300e-01, -1.13624819e-02,  1.30110517e-01,  4.55839247e-01,
#         3.93253118e-01,  6.09181039e-02, -4.06336725e-01, -4.03716266e-01,
#        -8.05642828e-02,  2.59448767e-01, -2.60547381e-02,  9.38183188e-01,
#        -8.59171301e-02,  5.14897764e-01,  4.12076013e-03, -5.78205764e-01,
#         1.09521024e-01,  8.61775279e-02, -3.37719023e-01,  8.63650262e-01,
#        -2.75409818e-01,  5.53615272e-01, -3.60831410e-01,  6.33384427e-03,
#        -1.65890530e-01,  2.31639549e-01,  7.29684234e-01, -1.41879380e-01,
#        -4.50755209e-01,  2.68655658e-01,  4.21587259e-01, -6.93539500e-01,
#        -3.71839702e-01,  8.36849153e-01,  1.96403012e-01,  4.94768977e-01,
#        -5.29095568e-02,  2.37732381e-01, -5.75322092e-01, -1.02481246e-01,
#        -8.14092159e-01,  7.81374335e-01, -5.56887388e-01,  1.81932911e-01,
#        -5.98374844e-01,  5.18788733e-02,  6.31073296e-01,  1.78298540e-02,
#         9.11941826e-02,  4.52668145e-02, -4.92434651e-01,  1.76434532e-01,
#         2.91648000e-01,  4.86164898e-01,  5.82740596e-03, -4.20045942e-01,
#         4.39781696e-01, -2.20695347e-01,  2.85797536e-01,  8.26253593e-01,
#         7.81208277e-02, -6.92146957e-01, -4.66643006e-01,  2.86605190e-02,
#        -1.97475016e-01, -1.16912343e-01,  5.08970737e-01,  4.38624233e-01,
#        -1.80200055e-01,  2.24037975e-01,  1.23636872e-01,  1.08331740e-01],
#       dtype=float32)

# %%
print(word_model.similarity('broadband', 'internet'))
print(word_model.similarity('company', 'firm'))
print(word_model.similarity('book', 'title'))
print(word_model.similarity('finance', 'title'))
# Out:
# 0.34940127
# 0.4806268
# 0.45864826
# -0.006742549
# /Users/shalu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# /Users/shalu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#
# /Users/shalu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/shalu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   after removing the cwd from sys.path.

# %%
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
    
word_model.most_similar('broadband')[:5]
# Out:
# [('wireless', 0.6458026766777039),
#  ('highspeed', 0.6268453598022461),
#  ('eiker', 0.612562894821167),
#  ('janitorial', 0.6116457581520081),
#  ('messaging', 0.6089986562728882)]
